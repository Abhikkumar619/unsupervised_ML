# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# Dataset link: https://www.kaggle.com/datasets/vjchoudhary7/customer-segmentation-tutorial-in-python

# %%
data=pd.read_csv('/content/Mall_Customers.csv')

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.shape
# Out:
# (200, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
x=data.loc[:,['Annual Income (k$)','Spending Score (1-100)']]

# %%
x.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
# Model fit in the array form-----> not needed
# x=data.loc[:,['Annual Income (k$)','Spending Score (1-100)']].values

# %%
x[:10]
# Out:
# array([[15, 39],
#        [15, 81],
#        [16,  6],
#        [16, 77],
#        [17, 40],
#        [17, 76],
#        [18,  6],
#        [18, 94],
#        [19,  3],
#        [19, 72]])

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(data=data, x='Annual Income (k$)', y='Spending Score (1-100)', hue='Gender', size="Spending Score (1-100)",sizes=(50, 500))
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
# calculating the within cluster sum of squared.
wcss=[]
for i in range(1,11):
  kmean=KMeans(n_clusters=i, init='k-means++')
  kmean.fit(x)
  wcss.append(kmean.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(1,11), wcss)
plt.title("WCSS graph")
plt.xlabel("N- cluster")
plt.ylabel("Distance")
plt.grid(True)

# %%
kmean=KMeans(n_clusters=5, init='k-means++')
kmean.fit(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
y_pred=kmean.fit_predict(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(data=data, x='Annual Income (k$)', y='Spending Score (1-100)', hue=y_pred, size="Spending Score (1-100)",sizes=(50, 500))
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
pip install kneed

# %%
score=silhouette_score(x, kmean.labels_)

# %%
score
# Out:
# 0.2968969162503008

# %%
silhouette_coefficent=[ ]
for k in range(2,11):
    kmean=KMeans(n_clusters=k,init='k-means++')
    kmean.fit(x)
    score=silhouette_score(x, kmean.labels_)
    silhouette_coefficent.append(score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
silhouette_coefficent
# Out:
# [0.2918426367691145,
#  0.46761358158775435,
#  0.4931963109249047,
#  0.553931997444648,
#  0.5367558067779578,
#  0.5288104473798049,
#  0.45697007065559897,
#  0.4565077334305076,
#  0.46188484812005554]

# %%
plt.plot(range(2,11), silhouette_coefficent)
plt.title("Accuracy score")
plt.xlabel("N-cluster")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')
